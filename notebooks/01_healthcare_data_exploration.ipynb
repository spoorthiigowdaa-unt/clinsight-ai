# %% [markdown]
# # CareGuard AI — Healthcare Data Exploration
#
# ## Phase 1: Exploratory Data Analysis
#
# This notebook explores synthetic healthcare data that will be used to build the CareGuard AI platform.
#
# ### Objectives
# - Understand patient demographics
# - Analyze healthcare encounters
# - Explore medical conditions
# - Analyze claims and healthcare utilization
# - Identify data-quality issues
# - Prepare features for machine-learning models
#
# ### Planned ML Tasks
# 1. Patient healthcare utilization risk prediction
# 2. Claims anomaly detection
# 3. Explainable AI for risk predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

pd.set_option("display.max_columns", None)

print("CareGuard AI environment ready!")
